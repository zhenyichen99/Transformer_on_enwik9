# %% [markdown]
# The first four cells are training records for 1 warm-up and 3 main training sessions. In the text generation tests, green texts are prompts and the rest is generated by the model.
# *Warning: There are gaps not included in these training records.*
#
# The last two cells are hold-out testing after the training is complete.
# *Warning: Only the very last cell calls `run.py` AS INCLUDED in this repo. All previous cells call different versions of `run.py`, which can be obtained by (un)commenting parts of the script and selecting models at various training stages (see `trained_models`).*

# %%
# starting model trained on 4k batches
# 100 epochs
# per epoch: 10 training batches and 5 validation batches
# sampling temperature = 0.2
# !python3 run.py
# Out:
# data loaded...
# model created...
#
# Epoch 1
# --------------------------------
# train_loss:   1.755239
# val_loss:     1.615498
#
# ...

# %%
# starting model trained on 24k batches
# 50 epochs
# per epoch: 1000 training batches and 50 validation batches
# sampling temperature = 0.3
# !python3 run.py
# Out:
# data loaded...
# model created...
#
# Epoch 1
# --------------------------------
# train_loss:   1.040932
# val_loss:     1.090362
#
# ...

# %%
# starting model trained on 74k batches
# 200 epochs
# per epoch: 1000 training batches and 50 validation batches
# sampling temperature = 0.3
# !python3 run.py
# Out:
# data loaded...
# model created...
#
# Epoch 1
# --------------------------------
# train_loss:   0.930577
# val_loss:     0.957010
#
# ...

# %%
# starting model trained on 274k batches
# 200 epochs
# per epoch: 1000 training batches and 50 validation batches per epoch
# sampling temperature = 0.5
# !python3 run.py
# Out:
# data loaded...
# model created...
#
# Epoch 1
# --------------------------------
# train_loss:   0.828797
# val_loss:     0.854156
#
# ...

# %%
# hold-out testing
# 1000 test batches
# !python3 run.py
# Out:
# data loaded...
# model created...
#
# test_loss:      0.854090
# bits_per_byte:  1.232192

# %%
# generating text from hold-out test prompts
# !python3 run.py
# Out:
# data loaded...
# model created...
#
# Prompt 1
# temp: 0.5
# --------------------------------
#
# ...
